# %%
import pandas as pd
import re
from bs4 import BeautifulSoup
import requests

# %%
URL_1987 ='https://en.wikipedia.org/wiki/1987_Rugby_World_Cup'
response_1987 = requests.get(URL_1987)
soup_1987 = BeautifulSoup(response_1987.text,'html.parser')
div_1987 = soup_1987.find('div', {'id':'mw-content-text'})
summary_1987 = div_1987.find_all('div',{'class':'vevent summary'})

# %%
events_1987 = []
for i in summary_1987:
    text = i.text
    events_1987.append(text)

# %%
events_clean_1987 = [e.replace('\n',' ').replace('\xa0', ' ').strip() for e in events_1987]

# %%
data_1987 = " ".join(events_clean_1987)

# %%
#datemethodregex
date_pattern = re.compile(r'\d{1,2}\s\w*\s1987')
dates = date_pattern.findall(data_1987)
date_list = []
for i in dates:
    date_list.append(i)

# %%
#team1
team1_pattern = re.compile(r'1987\s{4,5}(\w*|\w*\s\w*)\s{2,3}')
team1 = team1_pattern.findall(data_1987)
team1_list = []
for i in team1:
    team1_list.append(i)

#team2
team2_pattern = re.compile(r'[–]\d*\s{3}(\w*|\w*\s\w*)\s{3}\D{3}:')
team2 = team2_pattern.findall(data_1987)
team2_list = []
for i in team2:
    team2_list.append(i)

# %%
#score
score_pattern = re.compile(r'\d*[–]\d*')
scores = score_pattern.findall(data_1987)
scores_list = []
for i in scores:
    scores_list.append(i)

# %%
#points team 1
pt1_pattern = re.compile(r'\s{2,4}(\d*)[–]\d*\s{2,4}')
pt1 = pt1_pattern.findall(data_1987)
pt1_list = []
for i in pt1:
    pt1_list.append(i)
pt1_list = [ int(x) for x in pt1_list ]

#points team 2 
pt2_pattern = re.compile(r'\s{2,4}\d*[–](\d*)\s{2,4}')
pt2 = pt2_pattern.findall(data_1987)
pt2_list = []
for i in pt2:
    pt2_list.append(i)
pt2_list = [ int(x) for x in pt2_list ]

#total points
total_points_list =[]
for i,j in zip(pt1_list, pt2_list):
    k = i+j
    total_points_list.append(k)

# %%
#attendance
attendance_pattern = re.compile(r'Attendance:\s(\d*[,]\d*)')
attendance = attendance_pattern.findall(data_1987)
attendance_list = []
for i in attendance:
    attendance_list.append(i)

# %%
#referee
referee_pattern = re.compile(r'Referee:\s(\w*\s\w*)')
referee = referee_pattern.findall(data_1987)
referee_list = []
for i in referee:
    referee_list.append(i)

#referee nationality
ref_nationality_pattern = re.compile(r'[(](\D*\s\D*|\D*)[)]')
ref_nationality = ref_nationality_pattern.findall(data_1987)
referee_nationality_list = []
for i in ref_nationality:
    referee_nationality_list.append(i)

# %%
dico_1987 = {'Match Date':date_list,'Home Team': team1_list, 'Away Team' : team2_list, 'Score': scores_list, 'Points Home Team': pt1_list, 'Points Away Team' : pt2_list, 'Total Points': total_points_list, 'Attendance': attendance_list, 'Referee': referee_list, 'Referee Nationality': referee_nationality_list}
df_1987 = pd.DataFrame.from_dict(dico_1987, orient='index')
df_1987 = df_1987.transpose()
df_1987
# Out:
#       Match Date    Home Team      Away Team  Score Points Home Team  \
# 0    23 May 1987    Australia        England   19–6               19
# 1    24 May 1987        Japan  United States  18–21               18
# 2    30 May 1987      England          Japan   60–7               60
# 3    31 May 1987    Australia  United States  47–12               47
# 4    3 June 1987      England  United States   34–6               34
# 5    3 June 1987    Australia          Japan  42–23               42
# 6    24 May 1987       Canada          Tonga   37–4               37
# 7    25 May 1987      Ireland          Wales   6–13                6
# 8    29 May 1987        Tonga          Wales  16–29               16
# 9    30 May 1987       Canada        Ireland  19–46               19
# 10   3 June 1987       Canada          Wales   9–40                9
# 11   3 June 1987      Ireland          Tonga   32–9               32
# 12   22 May 1987  New Zealand          Italy   70–6               70
# ...

# %%
#df_1987.to_csv(r'C:\Users\lacar\DQ Projects\Rugby DataVis' + '\\1987.csv', index=False)
